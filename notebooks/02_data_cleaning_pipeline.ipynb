# %% [markdown]
# # Data Cleaning Pipeline - Exam Score Prediction

# %% [markdown]
# ## Addition to Project Idea Assignment
#
# With the **research question** being
#
# > "Can we predict exam scores based on a student’s academic behavior, study habits, lifestyle routines, and exam conditions?"
#
# and our **target variable** being the exam score percentage, we can not declare the exam score as a feature. And with that we have resolved our data leakage.

# %% [markdown]
# ---

# %% [markdown]
# ## My Data Cleaning Pipeline
#
# 0. Load dataset in Pandas
#    - Define and set relevant columns
# 1. Inspecting Data
#    - Getting an Initial Overview
# 2. Missing Data
#    - Identify missing values
#    - Visualize missing values
#    - [Handle missing values] - was not needed
# 3. Data Type Conversion
#    - Check data types
#    - Convert
# 4. Detecting & Removing Duplicates
#    - [Handle duplicates] - was not needed
# 5. Detecting & Handling Outliers
#    - Select numeric colums
#    - Statistics and Boxplots
#    - Identify Outliers with IQR-Method
#    - [Handling Outliers] - was not needed
# 6. Consistency & Standardization
#    - Check unique values for every categorial column
# 7. Final Check
#    - Check dimensions
#    - Check missing values
#    - Check data types
#    - Check df.head()
# 8. Saving the cleaned dataset

# %% [markdown]
# ---

# %% [markdown]
# ## Some Visualizations
#
# ### Missing Values
# - Dataset has no missing values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Outliers - Boxplots
#
# - Dataset has no Outliers.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ---

# %% [markdown]
# ## Meine Reflexion:
#
# 1. Welche Hauptprobleme hatte Ihr ursprünglicher Datensatz?
#    - Fast alle Spalten hatten den Datentypen *object*.
#    - Spalte *course* hatte indische Abschlüsse, welche wir nicht gewohnt sind (fehlende Klarheit).
#
# 2. Welche Bereinigungsschritte waren am wichtigsten?
#    - Allgemein ist die Behandlung von fehlenden und fehlerhaften Daten sowie Outliers am wichtigsten.
#    - Bei meinem Projekt waren es aber die *Data Type Conversion* und die *Consistency & Standardization*, welche besonders Klarheit und Konsistenz geschafft haben.
#
# 3. Wie viele Zeilen/Spalten haben Sie entfernt und warum?
#    - Es wurden keine Zeilen entfernt, da keine Zeile fehlerhaft oder ein Outlier ist. Der Datensatz war von Anfang an schon ziemlich sauber.
#    - Allerdings habe ich die Spalte *student_id* entfernt, da sie keinen wirklichen Zweck für die research question geboten hat und auch nicht unique war, weswegen sie nicht als Index dienen konnte.
#
# 4. Welche Herausforderungen gab es und wie haben Sie diese gelöst?
#    - Bei der *Data Type Conversion* war es etwas knifflig, die indischen courses den richtigen deutschen Abschlüssen zuzuordnen, weswegen ich Recherche in Google betreiben musste, um auch fachlich korrekt zu arbeiten.
#
# 5. Ist Ihr Datensatz jetzt bereit für die Analyse?
#    - Ja!
